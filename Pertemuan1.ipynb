# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelMatthew31/GoogleColab/blob/Image_Processing/Pertemuan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world!")
print("My name is Samuel Matthew")

age = 20
birth_place = "Jakarta"

print(f"I'm {age} years old and i was born in {birth_place}")
# Out:
# Hello world!
# My name is Samuel Matthew
# I'm 20 years old and i was born in Jakarta
